# %%
import pandas as pd

# %%
data = pd.read_csv('Advertising.csv')

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
x=data[['newspaper']]
y=data['sales']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Intercept (b0):", linear.intercept_)
print("Slope (b1):", linear.coef_)
# Out:
# Intercept (b0): 12.367587176537004
# Slope (b1): [0.06763487]

# %%
y_pred = linear.predict(x_test)

# %%
y_pred
# Out:
# array([13.60530536, 13.61206885, 13.93671624, 15.8304927 , 14.74833473,
#        14.37634292, 17.4402027 , 12.95601058, 16.82472535, 13.32800238,
#        16.06721476, 14.1193304 , 12.92895663, 13.01011848, 13.87584486,
#        13.15215171, 12.38787764, 12.95601058, 15.4585009 , 13.25360402,
#        17.2237711 , 12.97630104, 14.49808569, 14.7077538 , 13.81497347,
#        13.20625961, 13.55796095, 13.6932307 , 13.4226912 , 15.2961772 ,
#        20.07796277, 16.42567959, 14.8700775 , 13.93671624, 15.72227691,
#        13.95024322, 15.28265023, 16.31746379, 14.77538868, 14.37634292,
#        16.80443488, 12.5163839 , 13.21978658, 13.09128032, 16.2633559 ,
#        12.93572011, 12.43522205, 18.41414488, 17.72426916, 14.69422683,
#        14.51161267, 17.3860948 , 14.39663338, 13.8555544 , 13.76086557,
#        13.60530536, 15.28941372, 14.4439778 , 14.50484918, 15.16767094])

# %%
from sklearn.metrics import mean_squared_error , r2_score
mse = mean_squared_error (y_test,y_pred)
mse
# Out:
# 28.866496445407456

# %%
r2 =  r2_score(y_test,y_pred)
r2
# Out:
# -0.056459483731341464

# %%
len(x_test)
# Out:
# 60

# %%
len(y_pred)
# Out:
# 60

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test, y_test, color="blue", label="Actual")
plt.plot(x_test, y_pred, color="red", label="Predicted")
plt.title("Linear Regression Fit")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
